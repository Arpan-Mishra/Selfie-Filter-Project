# %%
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
X = np.load('Data/Image_array.npy',allow_pickle=True)
y = np.load('Data/Keypoints_array.npy',allow_pickle=True)

# %% [markdown]
# Creating Neural Network Architecture

# %%
model = tf.keras.Sequential()

#Convolution layer 1
model.add(tf.keras.layers.Conv2D(32,(4,4),input_shape = (96,96,1),activation = 'elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed = 0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.1))

#Convolution Layer 2
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed=0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.2))
          

#Convolution Layer 3
model.add(tf.keras.layers.Conv2D(128,(2,2),activation = 'elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed=0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.3))         


#Convolution Layer 4
model.add(tf.keras.layers.Conv2D(256,(1,1),activation = 'elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed=0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.4))    

# Flatten
model.add(tf.keras.layers.Flatten())     

# Fully Connected 1
model.add(tf.keras.layers.Dense(1000,activation='elu'))
model.add(tf.keras.layers.Dropout(0.5))    

# Fully Connected 2
model.add(tf.keras.layers.Dense(1000,activation='elu'))
model.add(tf.keras.layers.Dropout(0.6))    

# Output
model.add(tf.keras.layers.Dense(30,activation='linear'))

# %% [markdown]
# Model Compilation and Summary

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0003,beta_1=0.9,beta_2=0.99,epsilon=1e-8)

model.compile(optimizer=opt, loss = 'mean_squared_error',metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 93, 93, 32)        544
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 46, 46, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 128)       32896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 256)       33024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              6401000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              1001000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                30030
# =================================================================
# Total params: 7,516,990
# Trainable params: 7,516,990
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Splitting the data for training and Validation

# %%
from sklearn.model_selection import train_test_split

X_train,X_val,y_train,y_val = train_test_split(X,y,test_size = 0.2,shuffle = True, random_state = 0)

# sanity check
print('Train Images: '+ str(len(X_train)))
print('Train Keypoints: '+ str(len(y_train)))
print('Validation Images: '+ str(len(X_val)))
print('Validation Keypoints: '+ str(len(y_val)))
# Out:
# Train Images: 5639
# Train Keypoints: 5639
# Validation Images: 1410
# Validation Keypoints: 1410

# %% [markdown]
# Image Generator for Scaling and Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255., 
                                   zoom_range=0.1,
                                   rotation_range=20,
                                   #horizontal_flip=True,
                                   height_shift_range=0.1,
                                   width_shift_range = 0.2,
                                   fill_mode = 'nearest',
                                   brightness_range = [0.7,1.3])

validation_dategen = ImageDataGenerator(rescale=1./255.)

# %% [markdown]
# Fitting the Model

# %%
#parameters

batch_size = 128
epochs = 200

history = model.fit(train_datagen.flow(X_train,y_train,batch_size=batch_size),
                    epochs=epochs,
                    steps_per_epoch=len(X_train)//batch_size, 
                    validation_data = validation_dategen.flow(X_val,y_val,batch_size = batch_size),
                    validation_steps = len(X_val)//batch_size)
# Out:
# Epoch 1/200
# 44/44 [==============================] - 6s 131ms/step - loss: 12.6392 - mae: 2.4929 - val_loss: 6.2120 - val_mae: 1.5144
# Epoch 2/200
# 44/44 [==============================] - 6s 140ms/step - loss: 12.4039 - mae: 2.4606 - val_loss: 6.1640 - val_mae: 1.5320
# Epoch 3/200
# 44/44 [==============================] - 6s 139ms/step - loss: 12.5672 - mae: 2.4774 - val_loss: 6.1683 - val_mae: 1.5241
# Epoch 4/200
# 44/44 [==============================] - 6s 142ms/step - loss: 12.5499 - mae: 2.4853 - val_loss: 6.3817 - val_mae: 1.5896
# Epoch 5/200
# 44/44 [==============================] - 7s 153ms/step - loss: 12.3933 - mae: 2.4409 - val_loss: 6.3595 - val_mae: 1.5779
# Epoch 6/200
# 44/44 [==============================] - 7s 148ms/step - loss: 12.4370 - mae: 2.4751 - val_loss: 7.0489 - val_mae: 1.7847
# Epoch 7/200
# 44/44 [==============================] - 6s 132ms/step - loss: 12.2371 - mae: 2.4522 - val_loss: 6.0798 - val_mae: 1.4974
# Epoch 8/200
# 44/44 [==============================] - 6s 129ms/step - loss: 12.3983 - mae: 2.4775 - val_loss: 7.0568 - val_mae: 1.7640
# Epoch 9/200
# 44/44 [==============================] - 6s 129ms/step - loss: 12.4845 - mae: 2.4644 - val_loss: 6.0397 - val_mae: 1.4768
# Epoch 10/200
# 44/44 [==============================] - 6s 134ms/step - loss: 12.3729 - mae: 2.4618 - val_loss: 6.2458 - val_mae: 1.5950
# Epoch 11/200
# 44/44 [==============================] - 6s 133ms/step - loss: 12.6111 - mae: 2.4857 - val_loss: 6.1482 - val_mae: 1.4935
# Epoch 12/200
# 44/44 [==============================] - 6s 133ms/step - loss: 12.4453 - mae: 2.4842 - val_loss: 6.1509 - val_mae: 1.5094
# Epoch 13/200
# 44/44 [==============================] - 6s 130ms/step - loss: 12.4977 - mae: 2.4626 - val_loss: 6.2603 - val_mae: 1.5608
# Epoch 14/200
# 44/44 [==============================] - 6s 128ms/step - loss: 12.2473 - mae: 2.4488 - val_loss: 6.2904 - val_mae: 1.5651
# Epoch 15/200
# 44/44 [==============================] - 6s 128ms/step - loss: 12.1829 - mae: 2.4576 - val_loss: 5.9879 - val_mae: 1.4840
# Epoch 16/200
# 44/44 [==============================] - 6s 132ms/step - loss: 12.3920 - mae: 2.4698 - val_loss: 6.1739 - val_mae: 1.5233
# Epoch 17/200
# 44/44 [==============================] - 6s 132ms/step - loss: 12.6242 - mae: 2.4743 - val_loss: 6.3511 - val_mae: 1.5684
# Epoch 18/200
# 44/44 [==============================] - 6s 130ms/step - loss: 12.4466 - mae: 2.4679 - val_loss: 6.1339 - val_mae: 1.5504
# Epoch 19/200
# 44/44 [==============================] - 6s 132ms/step - loss: 12.0575 - mae: 2.4592 - val_loss: 6.1624 - val_mae: 1.5094
# Epoch 20/200
# Epoch 144/200
# 44/44 [==============================] - 6s 136ms/step - loss: 11.8067 - mae: 2.4049 - val_loss: 5.9680 - val_mae: 1.5090
# Epoch 145/200
# 44/44 [==============================] - 7s 149ms/step - loss: 11.8439 - mae: 2.4237 - val_loss: 5.9492 - val_mae: 1.5224
# Epoch 146/200
# 44/44 [==============================] - 7s 151ms/step - loss: 12.2003 - mae: 2.4418 - val_loss: 6.6593 - val_mae: 1.6899
# Epoch 147/200
# 44/44 [==============================] - 6s 138ms/step - loss: 11.7037 - mae: 2.4135 - val_loss: 6.0242 - val_mae: 1.5283
# Epoch 148/200
# 44/44 [==============================] - 6s 135ms/step - loss: 12.4965 - mae: 2.4588 - val_loss: 6.4497 - val_mae: 1.6724
# Epoch 149/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.8163 - mae: 2.4234 - val_loss: 5.8858 - val_mae: 1.4974
# Epoch 150/200
# 44/44 [==============================] - 6s 129ms/step - loss: 12.1405 - mae: 2.4250 - val_loss: 5.7391 - val_mae: 1.4338
# Epoch 151/200
# 44/44 [==============================] - 6s 130ms/step - loss: 11.7116 - mae: 2.4003 - val_loss: 6.6508 - val_mae: 1.6815
# Epoch 152/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.9769 - mae: 2.4293 - val_loss: 6.0079 - val_mae: 1.5396
# Epoch 153/200
# 44/44 [==============================] - 6s 128ms/step - loss: 12.1140 - mae: 2.4239 - val_loss: 6.4750 - val_mae: 1.6542
# Epoch 154/200
# 44/44 [==============================] - 6s 130ms/step - loss: 12.1498 - mae: 2.4413 - val_loss: 6.0681 - val_mae: 1.5529
# Epoch 155/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.6989 - mae: 2.4017 - val_loss: 6.6176 - val_mae: 1.7215
# Epoch 156/200
# 44/44 [==============================] - 6s 132ms/step - loss: 11.9622 - mae: 2.4171 - val_loss: 5.9970 - val_mae: 1.5291
# Epoch 157/200
# 44/44 [==============================] - 6s 133ms/step - loss: 11.9100 - mae: 2.4212 - val_loss: 6.2770 - val_mae: 1.6228
# Epoch 158/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.5926 - mae: 2.3836 - val_loss: 6.1900 - val_mae: 1.5366
# Epoch 159/200
# 44/44 [==============================] - 6s 128ms/step - loss: 12.5250 - mae: 2.4465 - val_loss: 6.4365 - val_mae: 1.7135
# Epoch 160/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.5265 - mae: 2.4105 - val_loss: 5.6886 - val_mae: 1.4195
# Epoch 161/200
# 44/44 [==============================] - 6s 129ms/step - loss: 12.3176 - mae: 2.4468 - val_loss: 5.9734 - val_mae: 1.5062
# Epoch 162/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.9684 - mae: 2.4242 - val_loss: 5.7689 - val_mae: 1.4357
# Epoch 163/200
# 44/44 [==============================] - 6s 133ms/step - loss: 11.7295 - mae: 2.4181 - val_loss: 5.7124 - val_mae: 1.4252
# Epoch 164/200
# 44/44 [==============================] - 6s 129ms/step - loss: 12.1617 - mae: 2.4361 - val_loss: 5.6774 - val_mae: 1.4252
# Epoch 165/200
# 44/44 [==============================] - 6s 142ms/step - loss: 11.5844 - mae: 2.3845 - val_loss: 5.5958 - val_mae: 1.3986
# Epoch 166/200
# 44/44 [==============================] - 6s 132ms/step - loss: 11.8671 - mae: 2.4058 - val_loss: 7.2772 - val_mae: 1.8700
# Epoch 167/200
# 44/44 [==============================] - 6s 132ms/step - loss: 11.8774 - mae: 2.4028 - val_loss: 6.7603 - val_mae: 1.7530
# Epoch 168/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.5991 - mae: 2.3939 - val_loss: 6.6714 - val_mae: 1.6799
# Epoch 169/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.7130 - mae: 2.3988 - val_loss: 6.1685 - val_mae: 1.5533
# Epoch 170/200
# 44/44 [==============================] - 6s 132ms/step - loss: 11.7956 - mae: 2.3926 - val_loss: 6.5372 - val_mae: 1.6776
# Epoch 171/200
# 44/44 [==============================] - 6s 144ms/step - loss: 11.6077 - mae: 2.3901 - val_loss: 7.0026 - val_mae: 1.7766
# Epoch 172/200
# 44/44 [==============================] - 6s 132ms/step - loss: 12.0701 - mae: 2.4208 - val_loss: 6.9879 - val_mae: 1.8430
# Epoch 173/200
# 44/44 [==============================] - 6s 133ms/step - loss: 11.7207 - mae: 2.4002 - val_loss: 5.9607 - val_mae: 1.5398
# Epoch 174/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.6618 - mae: 2.4004 - val_loss: 9.1143 - val_mae: 2.2160
# Epoch 175/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.8783 - mae: 2.4152 - val_loss: 6.0418 - val_mae: 1.5685
# Epoch 176/200
# 44/44 [==============================] - 6s 134ms/step - loss: 11.8793 - mae: 2.4234 - val_loss: 6.0542 - val_mae: 1.5211
# Epoch 177/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.9875 - mae: 2.4267 - val_loss: 6.6592 - val_mae: 1.7879
# Epoch 178/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.7416 - mae: 2.3917 - val_loss: 5.5766 - val_mae: 1.3996
# Epoch 179/200
# 44/44 [==============================] - 6s 139ms/step - loss: 11.9806 - mae: 2.4266 - val_loss: 6.1658 - val_mae: 1.6006
# Epoch 180/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.9418 - mae: 2.4194 - val_loss: 5.9593 - val_mae: 1.5246
# Epoch 181/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.8146 - mae: 2.4113 - val_loss: 6.3284 - val_mae: 1.6042
# Epoch 182/200
# 44/44 [==============================] - 6s 134ms/step - loss: 11.8758 - mae: 2.4373 - val_loss: 5.7326 - val_mae: 1.4459
# Epoch 183/200
# 44/44 [==============================] - 6s 130ms/step - loss: 11.9665 - mae: 2.4201 - val_loss: 5.6409 - val_mae: 1.4419
# Epoch 184/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.8624 - mae: 2.4031 - val_loss: 5.9861 - val_mae: 1.5219
# Epoch 185/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.9465 - mae: 2.4229 - val_loss: 6.4355 - val_mae: 1.6538
# Epoch 186/200
# 44/44 [==============================] - 6s 131ms/step - loss: 12.0370 - mae: 2.4311 - val_loss: 6.8561 - val_mae: 1.7987
# Epoch 187/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.6492 - mae: 2.3976 - val_loss: 5.6158 - val_mae: 1.4083
# Epoch 188/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.8089 - mae: 2.4127 - val_loss: 7.0414 - val_mae: 1.8224
# Epoch 189/200
# 44/44 [==============================] - 6s 128ms/step - loss: 12.0254 - mae: 2.4285 - val_loss: 6.6894 - val_mae: 1.7129
# Epoch 190/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.9840 - mae: 2.4315 - val_loss: 5.8333 - val_mae: 1.4840
# Epoch 191/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.2560 - mae: 2.3740 - val_loss: 5.9478 - val_mae: 1.5377
# Epoch 192/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.8385 - mae: 2.4008 - val_loss: 6.8261 - val_mae: 1.7940
# Epoch 193/200
# 44/44 [==============================] - 6s 128ms/step - loss: 12.0876 - mae: 2.4434 - val_loss: 6.2078 - val_mae: 1.5636
# Epoch 194/200
# 44/44 [==============================] - 6s 133ms/step - loss: 12.0932 - mae: 2.4148 - val_loss: 6.0370 - val_mae: 1.5291
# Epoch 195/200
# 44/44 [==============================] - 6s 130ms/step - loss: 11.6854 - mae: 2.3965 - val_loss: 6.8885 - val_mae: 1.7962
# Epoch 196/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.9794 - mae: 2.4285 - val_loss: 5.6713 - val_mae: 1.4299
# Epoch 197/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.6862 - mae: 2.4009 - val_loss: 5.8240 - val_mae: 1.4966
# Epoch 198/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.8134 - mae: 2.4085 - val_loss: 5.8381 - val_mae: 1.4844
# Epoch 199/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11.6062 - mae: 2.3819 - val_loss: 6.1116 - val_mae: 1.5462
# Epoch 200/200
# 44/44 [==============================] - 6s 130ms/step - loss: 11.7793 - mae: 2.4083 - val_loss: 6.7546 - val_mae: 1.7507

# %%
epochs_ticks = range(epochs)
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history['mae']
val_mae = history.history['val_mae']                   

# plotting loss
plt.figure(figsize=(10,8),dpi=60)
plt.title('Epochs vs Loss')
plt.plot(epochs_ticks,loss,'b-',label = 'Train Loss')
plt.plot(epochs_ticks,val_loss,'r-',label = 'Validation Loss')
plt.legend(loc = 'best')

# plotting metrics
plt.figure(figsize=(10,8),dpi=60)
plt.title('Epochs vs MAE')
plt.plot(epochs_ticks,mae,'b-',label = 'Train MAE')
plt.plot(epochs_ticks,val_mae,'r-',label = 'Validation MAE')
plt.legend(loc = 'best')

plt.show()

# %% [markdown]
# Plotting the predicted keypoints

# %%
prediction_val = model.predict(X_val/255.)

# %%
import random
i=0
for i in range(4):
    idx = random.randint(1,len(X_val))
    image = X[idx].reshape(96,96)
    keypoint_true = y_val[idx]
    keypoint_pred = prediction_val[idx]
    plt.imshow(image,cmap = 'gray')
    for i in range(1,31,2):
        plt.plot(keypoint_true[i-1],keypoint_true[i],'r.')
        plt.plot(keypoint_pred[i-1],keypoint_pred[i],'b.')
        plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# Saving the model

# %%
model.save('Keypoint_CNN.h5')
