# %%
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
X = np.load('Image_array.npy',allow_pickle=True)
y = np.load('Keypoints_array.npy',allow_pickle=True)

# %% [markdown]
# Creating Neural Network Architecture

# %%
model = tf.keras.Sequential()

#Convolution layer 1
model.add(tf.keras.layers.Conv2D(32,(4,4),input_shape = (96,96,1),activation = 'elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed = 0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.1))

#Convolution Layer 2
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed=0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.2))
          

#Convolution Layer 3
model.add(tf.keras.layers.Conv2D(128,(2,2),activation = 'elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed=0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.3))         


#Convolution Layer 4
model.add(tf.keras.layers.Conv2D(256,(1,1),activation = 'elu',
          kernel_initializer = tf.keras.initializers.GlorotUniform(seed=0)))
model.add(tf.keras.layers.MaxPool2D((2,2),strides=2))
model.add(tf.keras.layers.Dropout(0.4))    

# Flatten
model.add(tf.keras.layers.Flatten())     

# Fully Connected 1
model.add(tf.keras.layers.Dense(1000,activation='elu'))
model.add(tf.keras.layers.Dropout(0.5))    

# Fully Connected 2
model.add(tf.keras.layers.Dense(1000,activation='elu'))
model.add(tf.keras.layers.Dropout(0.6))    

# Output
model.add(tf.keras.layers.Dense(30,activation='linear'))

# %% [markdown]
# Model Compilation and Summary

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0005,beta_1=0.9,beta_2=0.99,epsilon=1e-8)

model.compile(optimizer=opt, loss = 'mean_squared_error',metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_44 (Conv2D)           (None, 93, 93, 32)        544
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 46, 46, 32)        0
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 21, 21, 128)       32896
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 10, 10, 256)       33024
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1000)              6401000
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1000)              1001000
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 30)                30030
# =================================================================
# Total params: 7,516,990
# Trainable params: 7,516,990
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Splitting the data for training and Validation

# %%
from sklearn.model_selection import train_test_split

X_train,X_val,y_train,y_val = train_test_split(X,y,test_size = 0.2,shuffle = True, random_state = 0)

# sanity check
print('Train Images: '+ str(len(X_train)))
print('Train Keypoints: '+ str(len(y_train)))
print('Validation Images: '+ str(len(X_val)))
print('Validation Keypoints: '+ str(len(y_val)))
# Out:
# Train Images: 5639
# Train Keypoints: 5639
# Validation Images: 1410
# Validation Keypoints: 1410

# %% [markdown]
# Image Generator for Scaling and Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255., 
                                   zoom_range=0.1,
                                   rotation_range=20,
                                   #horizontal_flip=True,
                                   height_shift_range=0.1,
                                   width_shift_range = 0.2,
                                   fill_mode = 'nearest',
                                   brightness_range = [0.7,1.3])

validation_dategen = ImageDataGenerator(rescale=1./255.)

# %% [markdown]
# Fitting the Model

# %%
#parameters

batch_size = 128
epochs = 200

history = model.fit(train_datagen.flow(X_train,y_train,batch_size=batch_size),
                    epochs=epochs,
                    steps_per_epoch=len(X_train)//batch_size, 
                    validation_data = validation_dategen.flow(X_val,y_val,batch_size = batch_size),
                    validation_steps = len(X_val)//batch_size)
# Out:
# Epoch 1/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.2834 - mae: 2.3566 - val_loss: 5.1135 - val_mae: 1.3236
# Epoch 2/200
# 44/44 [==============================] - 6s 125ms/step - loss: 11.4724 - mae: 2.3814 - val_loss: 5.2331 - val_mae: 1.3853
# Epoch 3/200
# 44/44 [==============================] - 6s 126ms/step - loss: 11.5036 - mae: 2.4020 - val_loss: 5.0328 - val_mae: 1.3092
# Epoch 4/200
# 44/44 [==============================] - 6s 133ms/step - loss: 11.4282 - mae: 2.3746 - val_loss: 5.2299 - val_mae: 1.3647
# Epoch 5/200
# 44/44 [==============================] - 6s 132ms/step - loss: 11.2428 - mae: 2.3783 - val_loss: 5.5088 - val_mae: 1.4704
# Epoch 6/200
# 44/44 [==============================] - 6s 139ms/step - loss: 11.4629 - mae: 2.3675 - val_loss: 5.1573 - val_mae: 1.3429
# Epoch 7/200
# 44/44 [==============================] - 6s 133ms/step - loss: 11.4309 - mae: 2.3802 - val_loss: 5.2770 - val_mae: 1.4007
# Epoch 8/200
# 44/44 [==============================] - 6s 131ms/step - loss: 11.3091 - mae: 2.3591 - val_loss: 6.0689 - val_mae: 1.6256
# Epoch 9/200
# 44/44 [==============================] - 6s 131ms/step - loss: 11.0725 - mae: 2.3346 - val_loss: 5.5726 - val_mae: 1.4842
# Epoch 10/200
# 44/44 [==============================] - 6s 129ms/step - loss: 11.5135 - mae: 2.3938 - val_loss: 5.5751 - val_mae: 1.5129
# Epoch 11/200
# 44/44 [==============================] - 6s 128ms/step - loss: 11.4252 - mae: 2.3938 - val_loss: 5.8049 - val_mae: 1.5653
# Epoch 12/200
# 44/44 [==============================] - 6s 126ms/step - loss: 11.4510 - mae: 2.3742 - val_loss: 5.3148 - val_mae: 1.4011
# Epoch 13/200
# 44/44 [==============================] - 6s 141ms/step - loss: 11.4793 - mae: 2.3715 - val_loss: 5.4363 - val_mae: 1.4227
# Epoch 14/200
# 44/44 [==============================] - 5s 124ms/step - loss: 11.4635 - mae: 2.3890 - val_loss: 6.2396 - val_mae: 1.7609
# Epoch 15/200
# 44/44 [==============================] - 5s 125ms/step - loss: 11.4058 - mae: 2.3761 - val_loss: 6.4188 - val_mae: 1.7971
# Epoch 16/200
# 44/44 [==============================] - 6s 126ms/step - loss: 11.4602 - mae: 2.4073 - val_loss: 5.5513 - val_mae: 1.5016
# Epoch 17/200
# 44/44 [==============================] - 6s 127ms/step - loss: 11
# 44/44 [==============================] - 6s 129ms/step - loss: 10.6519 - mae: 2.3104 - val_loss: 4.7880 - val_mae: 1.3293
# Epoch 189/200
# 44/44 [==============================] - 6s 131ms/step - loss: 10.7554 - mae: 2.3101 - val_loss: 4.8683 - val_mae: 1.3346
# Epoch 190/200
# 44/44 [==============================] - 6s 130ms/step - loss: 10.7765 - mae: 2.3256 - val_loss: 4.7481 - val_mae: 1.2624
# Epoch 191/200
# 44/44 [==============================] - 6s 131ms/step - loss: 10.5322 - mae: 2.3033 - val_loss: 4.7972 - val_mae: 1.3059
# Epoch 192/200
# 44/44 [==============================] - 6s 139ms/step - loss: 10.7745 - mae: 2.3254 - val_loss: 4.9803 - val_mae: 1.3904
# Epoch 193/200
# 44/44 [==============================] - 6s 129ms/step - loss: 10.4657 - mae: 2.2976 - val_loss: 4.7529 - val_mae: 1.2923
# Epoch 194/200
# 44/44 [==============================] - 6s 147ms/step - loss: 10.8248 - mae: 2.3281 - val_loss: 4.8970 - val_mae: 1.3463
# Epoch 195/200
# 44/44 [==============================] - 6s 135ms/step - loss: 10.6281 - mae: 2.3015 - val_loss: 4.7006 - val_mae: 1.2751
# Epoch 196/200
# 44/44 [==============================] - 6s 143ms/step - loss: 10.5323 - mae: 2.3106 - val_loss: 4.6691 - val_mae: 1.2634
# Epoch 197/200
# 44/44 [==============================] - 6s 138ms/step - loss: 10.5628 - mae: 2.3004 - val_loss: 4.7381 - val_mae: 1.2754
# Epoch 198/200
# 44/44 [==============================] - 6s 129ms/step - loss: 10.5571 - mae: 2.3031 - val_loss: 4.9321 - val_mae: 1.3518
# Epoch 199/200
# 44/44 [==============================] - 6s 132ms/step - loss: 10.6684 - mae: 2.3068 - val_loss: 5.1111 - val_mae: 1.4262
# Epoch 200/200
# 44/44 [==============================] - 6s 129ms/step - loss: 10.3391 - mae: 2.2961 - val_loss: 4.7544 - val_mae: 1.2854

# %%
epochs_ticks = range(epochs)
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history['mae']
val_mae = history.history['val_mae']                   

# plotting loss
plt.figure(figsize=(10,8),dpi=60)
plt.title('Epochs vs Loss')
plt.plot(epochs_ticks,loss,'b-',label = 'Train Loss')
plt.plot(epochs_ticks,val_loss,'r-',label = 'Validation Loss')
plt.legend(loc = 'best')

# plotting metrics
plt.figure(figsize=(10,8),dpi=60)
plt.title('Epochs vs MAE')
plt.plot(epochs_ticks,mae,'b-',label = 'Train MAE')
plt.plot(epochs_ticks,val_mae,'r-',label = 'Validation MAE')
plt.legend(loc = 'best')

plt.show()

# %% [markdown]
# Plotting the predicted keypoints

# %%
prediction_val = model.predict(X_val/255.)

# %%
import random
i=0
for i in range(4):
    idx = random.randint(1,len(X_val))
    image = X[idx].reshape(96,96)
    keypoint_true = y_val[idx]
    keypoint_pred = prediction_val[idx]
    plt.imshow(image,cmap = 'gray')
    for i in range(1,31,2):
        plt.plot(keypoint_true[i-1],keypoint_true[i],'r.')
        plt.plot(keypoint_pred[i-1],keypoint_pred[i],'b.')
        plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# Saving the model

# %%
model.save('Keypoint_CNN.h5')
